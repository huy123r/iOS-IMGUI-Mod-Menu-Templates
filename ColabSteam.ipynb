# %% [markdown]
# <a href="https://colab.research.google.com/github/huy123r/iOS-IMGUI-Mod-Menu-Templates/blob/main/ColabSteam.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#@title Bật cái này nếu m dùng mobile { display-mode: "form" }
# %%html
<b></b>Đéo để cái này chạy thì sẽ bị tắt máy đột ngột,trước khi tạo máy bật cái này lên<br/>
<audio autoplay="" src="https://github.com/hson010612-web/Colab-Cloud-Gaming/raw/refs/heads/main/silence.m4a" loop controls>
# Out:
# <b></b>Đéo để cái này chạy thì sẽ bị tắt máy đột ngột,trước khi tạo máy bật cái này lên<br/>
# <audio autoplay="" src="https://github.com/hson010612-web/Colab-Cloud-Gaming/raw/refs/heads/main/silence.m4a" loop controls>

# %%
#@title 🌐 Colab Region Check  { display-mode: "form" }

import subprocess
import time
from google.colab import runtime

# Get region
region = subprocess.check_output(
    "curl -s ipinfo.io | grep region | cut -d\\\" -f4",
    shell=True
).decode().strip()

print(f"Your current region: {region}")

try:
    print("Automatically keeping this runtime in 15 seconds... (Press Ctrl+C to unassign)")
    for i in range(15, 0, -1):
        print(f"{i}...", end="", flush=True)
        time.sleep(1)
    print("\nKeeping current runtime...")

except KeyboardInterrupt:
    print("\nCtrl+C detected — unassigning runtime...")
    runtime.unassign()

# %%
#@title 🖥️ Szz Cloud Colab T4 by SonwDev & NT.Hai { display-mode: "form" }
Mount_Google_Drive = False #@param {type:"boolean"}

if Mount_Google_Drive:
    from google.colab import drive
    drive.mount('/content/drive')
    print("✅ Drive mounted.")
else:
    print("⛔ Skipped mount.")

# !wget -q https://github.com/hson010612-web/Colab-Cloud-Gaming/raw/refs/heads/main/ColabSteam && chmod +x ColabSteam && ./ColabSteam
